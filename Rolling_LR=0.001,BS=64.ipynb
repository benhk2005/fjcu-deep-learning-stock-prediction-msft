# %% [markdown]
# <a href="https://colab.research.google.com/gist/benhk2005/0ef4d8caa9bbcfd14a280a3a0c33749e/2023-jun-6-2227.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
GLOBAL_BATCH_SIZE = 64
GLOBAL_LEARNING_RATE = 0.001

# %%
# Basic packages always been used
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Data scaling
from sklearn.preprocessing import MinMaxScaler

# Function for spilting training & testing data set
from sklearn.model_selection import train_test_split

# Tensorflow sequential models
from tensorflow import keras
from keras import backend as clear
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.optimizers import SGD
from keras.optimizers import Adam

# Functions for evaluation
from sklearn.metrics import mean_absolute_error #MAE
from sklearn.metrics import mean_squared_error #MSE,RMSE
from sklearn.metrics import mean_absolute_percentage_error #MAPE

# %% [markdown]
# # Note: Some metrics need to be defined manually

# %%
# Symmetric Mean Absolute Percentage Error (SMAPE)
def SMAPE_calulate(y_true, y_pred):
    n = len(y_true)
    SMAPE=(100 / n) * np.sum(2 * np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true)))
    return SMAPE

# Relative Absolute Error (RAE)
def RAE_calculate(y_true, y_pred):
    abs_errors = np.abs(y_true - y_pred)
    denominator = np.sum(np.abs(y_true - np.mean(y_true)))
    RAE=np.sum(abs_errors/denominator)
    return RAE

# Mean Relative Absolute Error (MRAE)
def MRAE_calculate(y_true, y_pred):
    n=len(y_true)
    abs_errors = np.abs(y_true - y_pred)
    denominator = np.sum(np.abs(y_true - np.mean(y_true)))
    RAE=np.sum(abs_errors/denominator)
    MRAE=RAE/n
    return MRAE

# Median Relative Absolute Error (MdRAE) comparing with benchmark
# Note: By default, the bench value is the mean of actual value
def MdRAE_calculate(y_true, y_pred, bench=None):
    if bench==None:
        bench=np.mean(y_true)
        MdRAE=np.median(np.abs(y_true - y_pred)/np.abs(y_true - bench))
        return MdRAE,bench
    else:
        MdRAE=np.median(np.abs(y_true - y_pred)/np.abs(y_true - bench))
        return MdRAE
    
# Relative Squared Error (RSE) & Root Relative Squared Error (RRSE)
def RSE_calculate(y_true, y_pred, Root=False):
    mse = np.mean((y_true - y_pred)**2)
    denominator = np.var(y_true)
    RSE=mse/denominator
    
    if Root==True:
        return np.sqrt(RSE)
    else:
        return RSE

# %%
#load data(sometimes need to use "/")
#df = pd.read_csv('D:/pythonData/python_demo_data/Rainfall_Forecast.csv')
# Colab
df = pd.read_csv('/content/drive/MyDrive/MSFT.csv')
df
# Out:
#            Date       Close
# 0      2/6/2014   40.790001
# 1      3/6/2014   40.290001
# 2      4/6/2014   40.320000
# 3      5/6/2014   41.209999
# 4      6/6/2014   41.480000
# ...         ...         ...
# 2260  23/5/2023  315.260010
# 2261  24/5/2023  313.850006
# 2262  25/5/2023  325.920013
# 2263  26/5/2023  332.890015
# 2264  30/5/2023  331.209991
#
# [2265 rows x 2 columns]

# %% [markdown]
# # 1. Preparations for time-series data

# %% [markdown]
# Note: Pandas has a specific data type for time-series data

# %%
# Date is converted into special data type of pandas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2265 non-null   object
#  1   Close   2265 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 35.5+ KB

# %%
# View descriptive statistics of target variable
# Pandas will automatically ignore date if the correct data type has been converted
new_df = df
new_df.describe()
# Out:
#              Close
# count  2265.000000
# mean    142.370631
# std      91.763318
# min      40.290001
# 25%      57.419998
# 50%     108.300003
# 75%     231.600006
# max     343.109985

# %%
# Plot Y and its corresponding date
# Figure setting
plt.figure(figsize=(24,8),dpi=300)
plt.title('MSFT Stock Price Between 2022 Jun 1 and 2023 May 31',weight='bold',fontsize=24)
plt.xlabel('Date',fontsize=18,weight='bold')
plt.ylabel('Relative Humidity',fontsize=18,weight='bold')

# Actual by predicted plot
plt.plot(new_df['Date'],new_df['Close'],marker='.',color='blue')

# Set the axis
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# # 2. Creating time lags as predictor variables

# %% [markdown]
# # Important!: Be caution when dealing with time-series data

# %% [markdown]
# python do have various packages and function that can deal with time-series data with ease, however, make sure that you understand the fundamental first!

# %%
# Create 3 lags
new_df['Lag_1']=new_df['Close'].shift(1).copy()
new_df['Lag_2']=new_df['Close'].shift(2).copy()
new_df['Lag_3']=new_df['Close'].shift(3).copy()
new_df.head()
# Out:
#        Date      Close      Lag_1      Lag_2      Lag_3
# 0  2/6/2014  40.790001        NaN        NaN        NaN
# 1  3/6/2014  40.290001  40.790001        NaN        NaN
# 2  4/6/2014  40.320000  40.290001  40.790001        NaN
# 3  5/6/2014  41.209999  40.320000  40.290001  40.790001
# 4  6/6/2014  41.480000  41.209999  40.320000  40.290001

# %%
# Drop out missing values and rest index
clean_df=new_df.dropna(axis=0, how='any').copy()
clean_df=clean_df.reset_index(drop=True)
clean_df
# Out:
#            Date       Close       Lag_1       Lag_2       Lag_3
# 0      5/6/2014   41.209999   40.320000   40.290001   40.790001
# 1      6/6/2014   41.480000   41.209999   40.320000   40.290001
# 2      9/6/2014   41.270000   41.480000   41.209999   40.320000
# 3     10/6/2014   41.110001   41.270000   41.480000   41.209999
# 4     11/6/2014   40.860001   41.110001   41.270000   41.480000
# ...         ...         ...         ...         ...         ...
# 2257  23/5/2023  315.260010  321.179993  318.339996  318.519989
# 2258  24/5/2023  313.850006  315.260010  321.179993  318.339996
# 2259  25/5/2023  325.920013  313.850006  315.260010  321.179993
# 2260  26/5/2023  332.890015  325.920013  313.850006  315.260010
# 2261  30/5/2023  331.209991  332.890015  325.920013  313.850006
#
# [2262 rows x 5 columns]

# %% [markdown]
# # 3. Data preprocessing under time-series structure

# %%
# Train data
Forecast_train_data=clean_df.iloc[0:1938,:].copy()
Forecast_train_data
# Out:
#            Date       Close       Lag_1       Lag_2       Lag_3
# 0      5/6/2014   41.209999   40.320000   40.290001   40.790001
# 1      6/6/2014   41.480000   41.209999   40.320000   40.290001
# 2      9/6/2014   41.270000   41.480000   41.209999   40.320000
# 3     10/6/2014   41.110001   41.270000   41.480000   41.209999
# 4     11/6/2014   40.860001   41.110001   41.270000   41.480000
# ...         ...         ...         ...         ...         ...
# 1933   7/2/2022  300.950012  305.940002  301.250000  313.459991
# 1934   8/2/2022  304.559998  300.950012  305.940002  301.250000
# 1935   9/2/2022  311.209991  304.559998  300.950012  305.940002
# 1936  10/2/2022  302.380005  311.209991  304.559998  300.950012
# 1937  11/2/2022  295.040009  302.380005  311.209991  304.559998
#
# [1938 rows x 5 columns]

# %%
# Test data
Forecast_test_data=clean_df.iloc[1938:1938+323,:].copy()
Forecast_test_data
# Out:
#            Date       Close       Lag_1       Lag_2       Lag_3
# 1938  14/2/2022  295.000000  295.040009  302.380005  311.209991
# 1939  15/2/2022  300.470001  295.000000  295.040009  302.380005
# 1940  16/2/2022  299.500000  300.470001  295.000000  295.040009
# 1941  17/2/2022  290.730011  299.500000  300.470001  295.000000
# 1942  18/2/2022  287.929993  290.730011  299.500000  300.470001
# ...         ...         ...         ...         ...         ...
# 2256  22/5/2023  321.179993  318.339996  318.519989  314.000000
# 2257  23/5/2023  315.260010  321.179993  318.339996  318.519989
# 2258  24/5/2023  313.850006  315.260010  321.179993  318.339996
# 2259  25/5/2023  325.920013  313.850006  315.260010  321.179993
# 2260  26/5/2023  332.890015  325.920013  313.850006  315.260010
#
# [323 rows x 5 columns]

# %% [markdown]
# # 4. Prepare time-series data for train/validation structure manually

# %% [markdown]
# # Rolling window

# %%
# Rolling 1
Rol_training_1=Forecast_train_data.iloc[0:966,:].copy()
Rol_val_1=Forecast_train_data.iloc[966:966+323,:].copy()

# Rolling 2
Rol_training_2=Forecast_train_data.iloc[320:1289,:].copy()
Rol_val_2=Forecast_train_data.iloc[1289:1289+323,:].copy()

# Rolling 3
Rol_training_3=Forecast_train_data.iloc[643:1612,:].copy()
Rol_val_3=Forecast_train_data.iloc[1612:1612+323,:].copy()

# %% [markdown]
# # 5. Set dependent variable(Y or target) & independent variable(X)

# %%
##1
#set x (make prediction)
# Train
x_train=Rol_training_1.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingT=MMscaler.fit_transform(x_train)
scaled_x_train=pd.DataFrame(data=scalingT)
scaled_x_train.columns=['Lag_1','Lag_2','Lag_3']

# Validation
x_val=Rol_val_1.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingV=MMscaler.fit_transform(x_val)
scaled_x_val=pd.DataFrame(data=scalingV)
scaled_x_val.columns=['Lag_1','Lag_2','Lag_3']

#set y (want to predict)
y_train=Rol_training_1['Close'].copy()
y_val=Rol_val_1['Close'].copy()

# %%
scaled_x_val.describe()
# Out:
#             Lag_1       Lag_2       Lag_3
# count  323.000000  323.000000  323.000000
# mean     0.424117    0.421322    0.424458
# std      0.238728    0.237883    0.234661
# min      0.000000    0.000000    0.000000
# 25%      0.250154    0.247072    0.252999
# 50%      0.369427    0.369427    0.375280
# 75%      0.561229    0.555887    0.554584
# max      1.000000    1.000000    1.000000

# %% [markdown]
# # 6. Creating Net

# %%
# Quick recap: Total of 12 features in the data set
scaled_x_train.head()
# Out:
#       Lag_1     Lag_2     Lag_3
# 0  0.000531  0.000000  0.008853
# 1  0.016289  0.000531  0.000000
# 2  0.021069  0.016289  0.000531
# 3  0.017351  0.021069  0.016289
# 4  0.014518  0.017351  0.021069

# %%
# Tips: Using shape to call the amount of features in the data set 
input_features=scaled_x_train.shape[1]
print('Amount of features:',input_features)
# Out:
# Amount of features: 3

# %%
from keras.losses import mse
from keras.backend import sqrt

def my_RMSE(y_true, y_pred):
    return sqrt(mse(y_true, y_pred))

# Register custom object
#from keras.utils.generic_utils import get_custom_objects for pc
from tensorflow.keras.saving import get_custom_objects
get_custom_objects().update({'my_RMSE': my_RMSE})
#get_custom_objects().update({'my_MAPE': MRAE_calculate})

# %% [markdown]
# # Sequential style coding for creating net

# %%
# 6.1 Create the model
clear.clear_session()
model=Sequential()

# 6.2 Add input layer & first hidden layer
model.add(Dense(units=6, input_dim=3, activation='relu'))

# 6.3 Add second hidden layer
model.add(Dense(units=12, activation='linear'))

model.add(Dropout(rate=0.2))

# 6.4 Add third hidden layer
model.add(Dense(units=24, activation='linear'))

model.add(Dense(units=48, activation='relu'))

model.add(Dropout(rate=0.4))

model.add(Dense(units=96, activation='relu'))

# 6.5 Add output layer
model.add(Dense(units=1, activation='linear'))

# 6.6 Compile the defined Net
#opt=SGD(learning_rate=0.001,momentum=0.5)
opt=Adam(learning_rate=GLOBAL_LEARNING_RATE,beta_1=0.95)
model.compile(loss='my_RMSE',optimizer=opt, metrics=['mean_absolute_percentage_error'])

# Finally check the model 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 24
#
#  dense_1 (Dense)             (None, 12)                84
#
#  dropout (Dropout)           (None, 12)                0
#
#  dense_2 (Dense)             (None, 24)                312
#
#  dense_3 (Dense)             (None, 48)                1200
#
#  dropout_1 (Dropout)         (None, 48)                0
#
#  dense_4 (Dense)             (None, 96)                4704
#
#  dense_5 (Dense)             (None, 1)                 97
#
# =================================================================
# Total params: 6,421
# Trainable params: 6,421
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 7. Fit the model (train/validation)

# %% [markdown]
# # Rolling 1

# %%
##1
#set x (make prediction)
# Train
x_train=Rol_training_1.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingT=MMscaler.fit_transform(x_train)
scaled_x_train=pd.DataFrame(data=scalingT)
scaled_x_train.columns=['Lag_1','Lag_2','Lag_3']

# Validation
x_val=Rol_val_1.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingV=MMscaler.fit_transform(x_val)
scaled_x_val=pd.DataFrame(data=scalingV)
scaled_x_val.columns=['Lag_1','Lag_2','Lag_3']

#set y (want to predict)
y_train=Rol_training_1['Close'].copy()
y_val=Rol_val_1['Close'].copy()

# %%
scaled_x_val.describe()
# Out:
#             Lag_1       Lag_2       Lag_3
# count  323.000000  323.000000  323.000000
# mean     0.424117    0.421322    0.424458
# std      0.238728    0.237883    0.234661
# min      0.000000    0.000000    0.000000
# 25%      0.250154    0.247072    0.252999
# 50%      0.369427    0.369427    0.375280
# 75%      0.561229    0.555887    0.554584
# max      1.000000    1.000000    1.000000

# %%
# 7.1 Store in the history for more useful information
history=model.fit(scaled_x_train, y_train, epochs=100, batch_size=GLOBAL_BATCH_SIZE,verbose=1,validation_data=(scaled_x_val, y_val))
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 17ms/step - loss: 58.0016 - mean_absolute_percentage_error: 99.5236 - val_loss: 110.1381 - val_mean_absolute_percentage_error: 99.2365
# Epoch 2/100
# 16/16 [==============================] - 0s 6ms/step - loss: 56.8319 - mean_absolute_percentage_error: 97.6198 - val_loss: 107.8615 - val_mean_absolute_percentage_error: 97.2353
# Epoch 3/100
# 16/16 [==============================] - 0s 6ms/step - loss: 53.6645 - mean_absolute_percentage_error: 92.3944 - val_loss: 101.4699 - val_mean_absolute_percentage_error: 91.6079
# Epoch 4/100
# 16/16 [==============================] - 0s 6ms/step - loss: 44.9611 - mean_absolute_percentage_error: 78.0120 - val_loss: 83.8120 - val_mean_absolute_percentage_error: 76.0426
# Epoch 5/100
# 16/16 [==============================] - 0s 5ms/step - loss: 22.4928 - mean_absolute_percentage_error: 40.2829 - val_loss: 40.5729 - val_mean_absolute_percentage_error: 37.8903
# Epoch 6/100
# 16/16 [==============================] - 0s 5ms/step - loss: 14.6875 - mean_absolute_percentage_error: 23.1916 - val_loss: 39.5843 - val_mean_absolute_percentage_error: 36.9388
# Epoch 7/100
# 16/16 [==============================] - 0s 6ms/step - loss: 11.1411 - mean_absolute_percentage_error: 19.3497 - val_loss: 53.3045 - val_mean_absolute_percentage_error: 48.9717
# Epoch 8/100
# 16/16 [==============================] - 0s 5ms/step - loss: 10.7102 - mean_absolute_percentage_error: 18.6962 - val_loss: 44.2650 - val_mean_absolute_percentage_error: 40.8657
# Epoch 9/100
# 16/16 [==============================] - 0s 6ms/step - loss: 10.1622 - mean_absolute_percentage_error: 16.8493 - val_loss: 45.8145 - val_mean_absolute_percentage_error: 42.1455
# Epoch 10/100
# 16/16 [==============================] - 0s 5ms/step - loss: 9.7099 - mean_absolute_percentage_error: 16.7075 - val_loss: 52.5187 - val_mean_absolute_percentage_error: 48.0210
# Epoch 11/100
# 16/16 [==============================] - 0s 6ms/step - loss: 8.9212 - mean_absolute_percentage_error: 15.1351 - val_loss: 43.3035 - val_mean_absolute_percentage_error: 39.7706
# Epoch 12/100
# 16/16 [==============================] - 0s 6ms/step - loss: 8.8611 - mean_absolute_percentage_error: 14.6656 - val_loss: 49.5271 - val_mean_absolute_percentage_error: 45.2520
# Epoch 13/100
# 16/16 [==============================] - 0s 5ms/step - loss: 8.3084 - mean_absolute_percentage_error: 14.1812 - val_loss: 49.4691 - val_mean_absolute_percentage_error: 45.1526
# Epoch 14/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.7738 - mean_absolute_percentage_error: 13.2336 - val_loss: 50.3290 - val_mean_absolute_percentage_error: 45.8745
# Epoch 15/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.8007 - mean_absolute_percentage_error: 13.2270 - val_loss: 47.6034 - val_mean_absolute_percentage_error: 43.4105
# Epoch 16/100
# 16/16 [==============================] - 0s 6ms/step - loss: 7.8122 - mean_absolute_percentage_error: 13.2880 - val_loss: 50.7368 - val_mean_absolute_percentage_error: 46.1984
# Epoch 17/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.5573 - mean_absolute_percentage_error: 12.8549 - val_loss: 48.1029 - val_mean_absolute_percentage_error: 43.8448
# Epoch 18/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.6229 - mean_absolute_percentage_error: 12.8566 - val_loss: 49.7466 - val_mean_absolute_percentage_error: 45.3154
# Epoch 19/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.6056 - mean_absolute_percentage_error: 12.9616 - val_loss: 49.0023 - val_mean_absolute_percentage_error: 44.6551
# Epoch 20/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.6206 - mean_absolute_percentage_error: 12.9047 - val_loss: 48.5873 - val_mean_absolute_percentage_error: 44.2935
# Epoch 21/100
# 16/16 [==============================] - 0s 6ms/step - loss: 7.2708 - mean_absolute_percentage_error: 12.3760 - val_loss: 50.9228 - val_mean_absolute_percentage_error: 46.3775
# Epoch 22/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.4055 - mean_absolute_percentage_error: 12.6190 - val_loss: 48.1184 - val_mean_absolute_percentage_error: 43.8786
# Epoch 23/100
# 16/16 [==============================] - 0s 7ms/step - loss: 7.2352 - mean_absolute_percentage_error: 12.1551 - val_loss: 50.1312 - val_mean_absolute_percentage_error: 45.6731
# Epoch 24/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9639 - mean_absolute_percentage_error: 11.7615 - val_loss: 49.7497 - val_mean_absolute_percentage_error: 45.3244
# Epoch 25/100
# 16/16 [==============================] - 0s 6ms/step - loss: 7.1368 - mean_absolute_percentage_error: 12.2079 - val_loss: 47.8276 - val_mean_absolute_percentage_error: 43.6089
# Epoch 26/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9516 - mean_absolute_percentage_error: 11.9309 - val_loss: 49.8095 - val_mean_absolute_percentage_error: 45.3796
# Epoch 27/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9496 - mean_absolute_percentage_error: 11.6949 - val_loss: 47.2462 - val_mean_absolute_percentage_error: 43.1072
# Epoch 28/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9890 - mean_absolute_percentage_error: 11.6667 - val_loss: 52.2338 - val_mean_absolute_percentage_error: 47.5503
# Epoch 29/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9655 - mean_absolute_percentage_error: 11.7304 - val_loss: 47.3825 - val_mean_absolute_percentage_error: 43.2180
# Epoch 30/100
# 16/16 [==============================] - 0s 6ms/step - loss: 7.0195 - mean_absolute_percentage_error: 11.9107 - val_loss: 51.7894 - val_mean_absolute_percentage_error: 47.1287
# Epoch 31/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4860 - mean_absolute_percentage_error: 10.8965 - val_loss: 48.6526 - val_mean_absolute_percentage_error: 44.3265
# Epoch 32/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4629 - mean_absolute_percentage_error: 10.8756 - val_loss: 49.0710 - val_mean_absolute_percentage_error: 44.6899
# Epoch 33/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5773 - mean_absolute_percentage_error: 11.1295 - val_loss: 49.4234 - val_mean_absolute_percentage_error: 45.0069
# Epoch 34/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3143 - mean_absolute_percentage_error: 10.6719 - val_loss: 49.4579 - val_mean_absolute_percentage_error: 45.0385
# Epoch 35/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.3616 - mean_absolute_percentage_error: 10.6996 - val_loss: 49.3204 - val_mean_absolute_percentage_error: 44.9062
# Epoch 36/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3897 - mean_absolute_percentage_error: 10.8343 - val_loss: 50.6104 - val_mean_absolute_percentage_error: 46.0534
# Epoch 37/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.0312 - mean_absolute_percentage_error: 10.1320 - val_loss: 48.9054 - val_mean_absolute_percentage_error: 44.5310
# Epoch 38/100
# 16/16 [==============================] - 0s 7ms/step - loss: 6.4834 - mean_absolute_percentage_error: 10.7797 - val_loss: 50.4509 - val_mean_absolute_percentage_error: 45.8953
# Epoch 39/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.2375 - mean_absolute_percentage_error: 10.4508 - val_loss: 49.9790 - val_mean_absolute_percentage_error: 45.4821
# Epoch 40/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.4865 - mean_absolute_percentage_error: 10.8136 - val_loss: 49.1647 - val_mean_absolute_percentage_error: 44.7497
# Epoch 41/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1669 - mean_absolute_percentage_error: 10.4329 - val_loss: 50.1088 - val_mean_absolute_percentage_error: 45.5740
# Epoch 42/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.8024 - mean_absolute_percentage_error: 9.8014 - val_loss: 50.4019 - val_mean_absolute_percentage_error: 45.8441
# Epoch 43/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.9392 - mean_absolute_percentage_error: 10.0406 - val_loss: 49.3735 - val_mean_absolute_percentage_error: 44.9296
# Epoch 44/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.2167 - mean_absolute_percentage_error: 10.4603 - val_loss: 49.5847 - val_mean_absolute_percentage_error: 45.1255
# Epoch 45/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.8748 - mean_absolute_percentage_error: 9.8360 - val_loss: 50.1367 - val_mean_absolute_percentage_error: 45.6188
# Epoch 46/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.4488 - mean_absolute_percentage_error: 10.7671 - val_loss: 48.7561 - val_mean_absolute_percentage_error: 44.3896
# Epoch 47/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9096 - mean_absolute_percentage_error: 10.0498 - val_loss: 51.8978 - val_mean_absolute_percentage_error: 47.1749
# Epoch 48/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.1935 - mean_absolute_percentage_error: 10.3057 - val_loss: 48.5730 - val_mean_absolute_percentage_error: 44.2053
# Epoch 49/100
# 16/16 [==============================] - 0s 8ms/step - loss: 6.0242 - mean_absolute_percentage_error: 10.1148 - val_loss: 51.0603 - val_mean_absolute_percentage_error: 46.4163
# Epoch 50/100
# 16/16 [==============================] - 0s 9ms/step - loss: 5.7010 - mean_absolute_percentage_error: 9.5452 - val_loss: 49.1615 - val_mean_absolute_percentage_error: 44.7315
# Epoch 51/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.8051 - mean_absolute_percentage_error: 9.8224 - val_loss: 51.5939 - val_mean_absolute_percentage_error: 46.9183
# Epoch 52/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.7514 - mean_absolute_percentage_error: 9.5857 - val_loss: 48.3887 - val_mean_absolute_percentage_error: 44.0940
# Epoch 53/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.8517 - mean_absolute_percentage_error: 10.0144 - val_loss: 52.2123 - val_mean_absolute_percentage_error: 47.5015
# Epoch 54/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.6309 - mean_absolute_percentage_error: 9.5138 - val_loss: 48.7452 - val_mean_absolute_percentage_error: 44.3986
# Epoch 55/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.4546 - mean_absolute_percentage_error: 9.2310 - val_loss: 50.4868 - val_mean_absolute_percentage_error: 45.9339
# Epoch 56/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.7232 - mean_absolute_percentage_error: 9.5762 - val_loss: 50.7134 - val_mean_absolute_percentage_error: 46.1375
# Epoch 57/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.7724 - mean_absolute_percentage_error: 9.5989 - val_loss: 49.6617 - val_mean_absolute_percentage_error: 45.2036
# Epoch 58/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.4229 - mean_absolute_percentage_error: 9.2295 - val_loss: 50.9459 - val_mean_absolute_percentage_error: 46.3338
# Epoch 59/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.7019 - mean_absolute_percentage_error: 9.5716 - val_loss: 49.3130 - val_mean_absolute_percentage_error: 44.8663
# Epoch 60/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.6116 - mean_absolute_percentage_error: 9.4450 - val_loss: 49.8828 - val_mean_absolute_percentage_error: 45.3667
# Epoch 61/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.4593 - mean_absolute_percentage_error: 9.1739 - val_loss: 50.7646 - val_mean_absolute_percentage_error: 46.1607
# Epoch 62/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.5121 - mean_absolute_percentage_error: 9.1538 - val_loss: 48.9073 - val_mean_absolute_percentage_error: 44.5058
# Epoch 63/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.4449 - mean_absolute_percentage_error: 9.0779 - val_loss: 51.0033 - val_mean_absolute_percentage_error: 46.3695
# Epoch 64/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.6636 - mean_absolute_percentage_error: 9.4430 - val_loss: 50.7310 - val_mean_absolute_percentage_error: 46.1306
# Epoch 65/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.7457 - mean_absolute_percentage_error: 9.6291 - val_loss: 48.9474 - val_mean_absolute_percentage_error: 44.5433
# Epoch 66/100
# 16/16 [==============================] - 0s 9ms/step - loss: 5.5669 - mean_absolute_percentage_error: 9.3788 - val_loss: 52.2024 - val_mean_absolute_percentage_error: 47.4257
# Epoch 67/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.4058 - mean_absolute_percentage_error: 9.1572 - val_loss: 49.2551 - val_mean_absolute_percentage_error: 44.8012
# Epoch 68/100
# 16/16 [==============================] - 0s 9ms/step - loss: 5.4804 - mean_absolute_percentage_error: 9.1163 - val_loss: 49.7098 - val_mean_absolute_percentage_error: 45.1936
# Epoch 69/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.1488 - mean_absolute_percentage_error: 8.6001 - val_loss: 51.6100 - val_mean_absolute_percentage_error: 46.9074
# Epoch 70/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.3280 - mean_absolute_percentage_error: 8.9379 - val_loss: 49.0950 - val_mean_absolute_percentage_error: 44.6695
# Epoch 71/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.1920 - mean_absolute_percentage_error: 8.8214 - val_loss: 51.4725 - val_mean_absolute_percentage_error: 46.7983
# Epoch 72/100
# 16/16 [==============================] - 0s 9ms/step - loss: 5.0782 - mean_absolute_percentage_error: 8.5659 - val_loss: 49.9354 - val_mean_absolute_percentage_error: 45.4430
# Epoch 73/100
# 16/16 [==============================] - 0s 8ms/step - loss: 4.8914 - mean_absolute_percentage_error: 8.2009 - val_loss: 49.9897 - val_mean_absolute_percentage_error: 45.4837
# Epoch 74/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.4081 - mean_absolute_percentage_error: 8.9638 - val_loss: 48.7268 - val_mean_absolute_percentage_error: 44.3422
# Epoch 75/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.3843 - mean_absolute_percentage_error: 9.1479 - val_loss: 51.5336 - val_mean_absolute_percentage_error: 46.8368
# Epoch 76/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.4784 - mean_absolute_percentage_error: 9.1641 - val_loss: 50.8405 - val_mean_absolute_percentage_error: 46.2539
# Epoch 77/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.2057 - mean_absolute_percentage_error: 8.7185 - val_loss: 48.6648 - val_mean_absolute_percentage_error: 44.3361
# Epoch 78/100
# 16/16 [==============================] - 0s 9ms/step - loss: 5.1559 - mean_absolute_percentage_error: 8.6395 - val_loss: 51.6510 - val_mean_absolute_percentage_error: 46.9940
# Epoch 79/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.2561 - mean_absolute_percentage_error: 8.7205 - val_loss: 50.1031 - val_mean_absolute_percentage_error: 45.5708
# Epoch 80/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.2632 - mean_absolute_percentage_error: 8.8103 - val_loss: 52.1663 - val_mean_absolute_percentage_error: 47.3853
# Epoch 81/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.0956 - mean_absolute_percentage_error: 8.4738 - val_loss: 49.5091 - val_mean_absolute_percentage_error: 45.0183
# Epoch 82/100
# 16/16 [==============================] - 0s 8ms/step - loss: 4.8668 - mean_absolute_percentage_error: 8.1575 - val_loss: 51.3849 - val_mean_absolute_percentage_error: 46.7134
# Epoch 83/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.2439 - mean_absolute_percentage_error: 8.8391 - val_loss: 51.0544 - val_mean_absolute_percentage_error: 46.4410
# Epoch 84/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.0302 - mean_absolute_percentage_error: 8.4528 - val_loss: 49.9876 - val_mean_absolute_percentage_error: 45.4865
# Epoch 85/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.1229 - mean_absolute_percentage_error: 8.6012 - val_loss: 53.1805 - val_mean_absolute_percentage_error: 48.3372
# Epoch 86/100
# 16/16 [==============================] - 0s 8ms/step - loss: 5.0044 - mean_absolute_percentage_error: 8.3907 - val_loss: 48.7863 - val_mean_absolute_percentage_error: 44.4112
# Epoch 87/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.1107 - mean_absolute_percentage_error: 8.4925 - val_loss: 52.8639 - val_mean_absolute_percentage_error: 48.0268
# Epoch 88/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.0277 - mean_absolute_percentage_error: 8.3275 - val_loss: 49.4401 - val_mean_absolute_percentage_error: 44.9584
# Epoch 89/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.8266 - mean_absolute_percentage_error: 8.0746 - val_loss: 50.4584 - val_mean_absolute_percentage_error: 45.8512
# Epoch 90/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.9359 - mean_absolute_percentage_error: 8.2843 - val_loss: 50.4733 - val_mean_absolute_percentage_error: 45.8749
# Epoch 91/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.7074 - mean_absolute_percentage_error: 7.8726 - val_loss: 51.0183 - val_mean_absolute_percentage_error: 46.3838
# Epoch 92/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.8293 - mean_absolute_percentage_error: 8.1059 - val_loss: 49.4300 - val_mean_absolute_percentage_error: 44.9901
# Epoch 93/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.7839 - mean_absolute_percentage_error: 8.0193 - val_loss: 51.0387 - val_mean_absolute_percentage_error: 46.4119
# Epoch 94/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.7996 - mean_absolute_percentage_error: 8.0051 - val_loss: 50.4824 - val_mean_absolute_percentage_error: 45.9162
# Epoch 95/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.6626 - mean_absolute_percentage_error: 7.8772 - val_loss: 49.8613 - val_mean_absolute_percentage_error: 45.3687
# Epoch 96/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.8529 - mean_absolute_percentage_error: 8.1876 - val_loss: 49.8816 - val_mean_absolute_percentage_error: 45.4023
# Epoch 97/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.8980 - mean_absolute_percentage_error: 8.1568 - val_loss: 50.4602 - val_mean_absolute_percentage_error: 45.9081
# Epoch 98/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.7588 - mean_absolute_percentage_error: 8.0708 - val_loss: 50.7259 - val_mean_absolute_percentage_error: 46.1237
# Epoch 99/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.8989 - mean_absolute_percentage_error: 8.1637 - val_loss: 50.1560 - val_mean_absolute_percentage_error: 45.6074
# Epoch 100/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.6723 - mean_absolute_percentage_error: 7.7356 - val_loss: 50.3255 - val_mean_absolute_percentage_error: 45.7571

# %%
# Check the dictionary keys
modeling_result=history.history
modeling_result.keys()
# Out:
# dict_keys(['loss', 'mean_absolute_percentage_error', 'val_loss', 'val_mean_absolute_percentage_error'])

# %%
# 7.2 Plot the history of training and validation
training_loss_values=modeling_result['loss']
val_loss_values=modeling_result['val_loss']
epochs=range(1,len(training_loss_values)+1)

plt.figure(figsize=(12,10),dpi=300)
plt.xlabel('Epochs',fontsize=20)
plt.ylabel('Loss (Mean absolute percentage error, MAPE)',fontsize=20)
plt.title('Rainfall ANN training & validation of Loss result ',fontsize=20)

plt.plot(epochs, training_loss_values,marker='.',label='training Loss')
plt.plot(epochs, val_loss_values,marker='.',label='validation Loss')
plt.legend(loc=1,fontsize=24)
plt.show()

# %%
# 7.2 Plot the history of training and validation
training_acc_values=modeling_result['mean_absolute_percentage_error']
val_acc_values=modeling_result['val_mean_absolute_percentage_error']
epochs=range(1,len(training_acc_values)+1)

plt.figure(figsize=(12,10),dpi=300)
plt.xlabel('Epochs',fontsize=20)
plt.ylabel('Mean Absolute Percentage Error, MAPE',fontsize=20)
plt.title('Rainfall ANN training & validation of MAPE result ',fontsize=20)

plt.plot(epochs, training_acc_values,marker='.',label='training MAPE')
plt.plot(epochs, val_acc_values,marker='.',label='validation MAPE')
plt.legend(loc=1,fontsize=24)
plt.show()

# %% [markdown]
# # Rolling 2

# %%
##1
#set x (make prediction)
# Train
x_train=Rol_training_2.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingT=MMscaler.fit_transform(x_train)
scaled_x_train=pd.DataFrame(data=scalingT)
scaled_x_train.columns=['Lag_1','Lag_2','Lag_3']

# Validation
x_val=Rol_val_2.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingV=MMscaler.fit_transform(x_val)
scaled_x_val=pd.DataFrame(data=scalingV)
scaled_x_val.columns=['Lag_1','Lag_2','Lag_3']

#set y (want to predict)
y_train=Rol_training_2['Close'].copy()
y_val=Rol_val_2['Close'].copy()

# %%
x_train.describe()
# Out:
#             Lag_1       Lag_2       Lag_3
# count  969.000000  969.000000  969.000000
# mean    80.163375   80.067193   79.971022
# std     25.201565   25.165035   25.124966
# min     43.040001   43.040001   43.040001
# 25%     57.389999   57.250000   57.250000
# 50%     73.160004   73.050003   73.040001
# 75%    102.320000  102.190002  102.120003
# max    138.899994  138.899994  138.899994

# %%
# 7.1 Store in the history for more useful information
history=model.fit(scaled_x_train, y_train, epochs=100, batch_size=GLOBAL_BATCH_SIZE,verbose=1,validation_data=(scaled_x_val, y_val))
# Out:
# Epoch 1/100
# 16/16 [==============================] - 0s 11ms/step - loss: 12.5317 - mean_absolute_percentage_error: 14.9982 - val_loss: 84.5515 - val_mean_absolute_percentage_error: 50.0767
# Epoch 2/100
# 16/16 [==============================] - 0s 6ms/step - loss: 9.1211 - mean_absolute_percentage_error: 10.9462 - val_loss: 97.6901 - val_mean_absolute_percentage_error: 57.5370
# Epoch 3/100
# 16/16 [==============================] - 0s 6ms/step - loss: 8.0486 - mean_absolute_percentage_error: 9.7730 - val_loss: 95.5485 - val_mean_absolute_percentage_error: 56.4930
# Epoch 4/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.4304 - mean_absolute_percentage_error: 8.8132 - val_loss: 94.7437 - val_mean_absolute_percentage_error: 56.1590
# Epoch 5/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.1013 - mean_absolute_percentage_error: 8.4373 - val_loss: 93.7675 - val_mean_absolute_percentage_error: 55.6268
# Epoch 6/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.3546 - mean_absolute_percentage_error: 8.6891 - val_loss: 96.3937 - val_mean_absolute_percentage_error: 57.0457
# Epoch 7/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9097 - mean_absolute_percentage_error: 8.2165 - val_loss: 96.0647 - val_mean_absolute_percentage_error: 56.7965
# Epoch 8/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9445 - mean_absolute_percentage_error: 8.1713 - val_loss: 93.6049 - val_mean_absolute_percentage_error: 55.4253
# Epoch 9/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.7607 - mean_absolute_percentage_error: 8.1621 - val_loss: 96.5820 - val_mean_absolute_percentage_error: 57.1012
# Epoch 10/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.1511 - mean_absolute_percentage_error: 8.5419 - val_loss: 94.2489 - val_mean_absolute_percentage_error: 55.8191
# Epoch 11/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9826 - mean_absolute_percentage_error: 8.3645 - val_loss: 94.7368 - val_mean_absolute_percentage_error: 56.0779
# Epoch 12/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.7735 - mean_absolute_percentage_error: 8.1488 - val_loss: 95.1063 - val_mean_absolute_percentage_error: 56.2900
# Epoch 13/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.1217 - mean_absolute_percentage_error: 8.4645 - val_loss: 94.5083 - val_mean_absolute_percentage_error: 55.9733
# Epoch 14/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.7493 - mean_absolute_percentage_error: 8.1300 - val_loss: 96.5203 - val_mean_absolute_percentage_error: 57.0578
# Epoch 15/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5117 - mean_absolute_percentage_error: 7.8325 - val_loss: 94.7378 - val_mean_absolute_percentage_error: 56.0320
# Epoch 16/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.3645 - mean_absolute_percentage_error: 7.7071 - val_loss: 96.0175 - val_mean_absolute_percentage_error: 56.7409
# Epoch 17/100
# 16/16 [==============================] - 0s 7ms/step - loss: 6.7574 - mean_absolute_percentage_error: 8.1512 - val_loss: 96.3755 - val_mean_absolute_percentage_error: 56.9757
# Epoch 18/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.7545 - mean_absolute_percentage_error: 8.1346 - val_loss: 93.9873 - val_mean_absolute_percentage_error: 55.6577
# Epoch 19/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.5275 - mean_absolute_percentage_error: 7.7334 - val_loss: 95.9513 - val_mean_absolute_percentage_error: 56.7780
# Epoch 20/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.2056 - mean_absolute_percentage_error: 7.4138 - val_loss: 96.0099 - val_mean_absolute_percentage_error: 56.7763
# Epoch 21/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3879 - mean_absolute_percentage_error: 7.5856 - val_loss: 93.7178 - val_mean_absolute_percentage_error: 55.4885
# Epoch 22/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8226 - mean_absolute_percentage_error: 8.0928 - val_loss: 95.8983 - val_mean_absolute_percentage_error: 56.6922
# Epoch 23/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1717 - mean_absolute_percentage_error: 7.3897 - val_loss: 96.2238 - val_mean_absolute_percentage_error: 56.8537
# Epoch 24/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.4452 - mean_absolute_percentage_error: 7.7040 - val_loss: 95.3405 - val_mean_absolute_percentage_error: 56.3859
# Epoch 25/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.2489 - mean_absolute_percentage_error: 7.4603 - val_loss: 94.8789 - val_mean_absolute_percentage_error: 56.1825
# Epoch 26/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.1708 - mean_absolute_percentage_error: 7.4101 - val_loss: 96.8837 - val_mean_absolute_percentage_error: 57.2744
# Epoch 27/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6292 - mean_absolute_percentage_error: 8.0077 - val_loss: 94.2563 - val_mean_absolute_percentage_error: 55.7842
# Epoch 28/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.5358 - mean_absolute_percentage_error: 7.8000 - val_loss: 94.8667 - val_mean_absolute_percentage_error: 56.0999
# Epoch 29/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.3324 - mean_absolute_percentage_error: 7.6289 - val_loss: 97.7797 - val_mean_absolute_percentage_error: 57.7333
# Epoch 30/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5137 - mean_absolute_percentage_error: 7.7717 - val_loss: 94.2161 - val_mean_absolute_percentage_error: 55.7453
# Epoch 31/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1495 - mean_absolute_percentage_error: 7.3669 - val_loss: 94.4919 - val_mean_absolute_percentage_error: 55.9424
# Epoch 32/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1882 - mean_absolute_percentage_error: 7.3528 - val_loss: 97.7040 - val_mean_absolute_percentage_error: 57.7504
# Epoch 33/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3138 - mean_absolute_percentage_error: 7.5051 - val_loss: 95.3218 - val_mean_absolute_percentage_error: 56.3860
# Epoch 34/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0493 - mean_absolute_percentage_error: 7.2470 - val_loss: 94.7952 - val_mean_absolute_percentage_error: 56.0901
# Epoch 35/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1371 - mean_absolute_percentage_error: 7.2696 - val_loss: 96.5361 - val_mean_absolute_percentage_error: 57.0272
# Epoch 36/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2763 - mean_absolute_percentage_error: 7.5270 - val_loss: 95.7725 - val_mean_absolute_percentage_error: 56.5957
# Epoch 37/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0470 - mean_absolute_percentage_error: 7.1865 - val_loss: 95.2411 - val_mean_absolute_percentage_error: 56.2956
# Epoch 38/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1299 - mean_absolute_percentage_error: 7.3525 - val_loss: 96.3359 - val_mean_absolute_percentage_error: 56.9067
# Epoch 39/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9314 - mean_absolute_percentage_error: 7.1385 - val_loss: 95.0958 - val_mean_absolute_percentage_error: 56.2089
# Epoch 40/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.4065 - mean_absolute_percentage_error: 7.6221 - val_loss: 93.5017 - val_mean_absolute_percentage_error: 55.3385
# Epoch 41/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6110 - mean_absolute_percentage_error: 7.7951 - val_loss: 98.4168 - val_mean_absolute_percentage_error: 58.1033
# Epoch 42/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1333 - mean_absolute_percentage_error: 7.3062 - val_loss: 94.0128 - val_mean_absolute_percentage_error: 55.6789
# Epoch 43/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9296 - mean_absolute_percentage_error: 7.1591 - val_loss: 96.6290 - val_mean_absolute_percentage_error: 57.0734
# Epoch 44/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.3392 - mean_absolute_percentage_error: 7.5447 - val_loss: 97.0992 - val_mean_absolute_percentage_error: 57.3125
# Epoch 45/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.1235 - mean_absolute_percentage_error: 7.2301 - val_loss: 94.1347 - val_mean_absolute_percentage_error: 55.6533
# Epoch 46/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.0804 - mean_absolute_percentage_error: 7.2774 - val_loss: 96.1984 - val_mean_absolute_percentage_error: 56.8270
# Epoch 47/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.6761 - mean_absolute_percentage_error: 6.7395 - val_loss: 96.4253 - val_mean_absolute_percentage_error: 56.9512
# Epoch 48/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.8543 - mean_absolute_percentage_error: 6.9665 - val_loss: 96.2999 - val_mean_absolute_percentage_error: 56.8590
# Epoch 49/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.4835 - mean_absolute_percentage_error: 6.5724 - val_loss: 95.9276 - val_mean_absolute_percentage_error: 56.6632
# Epoch 50/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.5086 - mean_absolute_percentage_error: 6.5468 - val_loss: 96.3803 - val_mean_absolute_percentage_error: 56.9415
# Epoch 51/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.8851 - mean_absolute_percentage_error: 7.0046 - val_loss: 97.9931 - val_mean_absolute_percentage_error: 57.8371
# Epoch 52/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.5825 - mean_absolute_percentage_error: 6.6684 - val_loss: 95.9908 - val_mean_absolute_percentage_error: 56.6808
# Epoch 53/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.7847 - mean_absolute_percentage_error: 6.8675 - val_loss: 96.6523 - val_mean_absolute_percentage_error: 57.0895
# Epoch 54/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.6260 - mean_absolute_percentage_error: 6.7202 - val_loss: 95.7438 - val_mean_absolute_percentage_error: 56.5759
# Epoch 55/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.6127 - mean_absolute_percentage_error: 6.6910 - val_loss: 96.8144 - val_mean_absolute_percentage_error: 57.1472
# Epoch 56/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.5088 - mean_absolute_percentage_error: 6.5546 - val_loss: 98.2760 - val_mean_absolute_percentage_error: 57.9180
# Epoch 57/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.3943 - mean_absolute_percentage_error: 6.4615 - val_loss: 97.2074 - val_mean_absolute_percentage_error: 57.3119
# Epoch 58/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.4508 - mean_absolute_percentage_error: 6.4432 - val_loss: 94.5728 - val_mean_absolute_percentage_error: 55.8867
# Epoch 59/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.4936 - mean_absolute_percentage_error: 6.4678 - val_loss: 98.8902 - val_mean_absolute_percentage_error: 58.3506
# Epoch 60/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.4857 - mean_absolute_percentage_error: 6.5571 - val_loss: 96.2277 - val_mean_absolute_percentage_error: 56.8545
# Epoch 61/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.0778 - mean_absolute_percentage_error: 5.9484 - val_loss: 97.9574 - val_mean_absolute_percentage_error: 57.7170
# Epoch 62/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.2470 - mean_absolute_percentage_error: 6.2915 - val_loss: 97.3484 - val_mean_absolute_percentage_error: 57.3697
# Epoch 63/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.8588 - mean_absolute_percentage_error: 5.8296 - val_loss: 96.6080 - val_mean_absolute_percentage_error: 56.9980
# Epoch 64/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.3355 - mean_absolute_percentage_error: 6.3875 - val_loss: 98.0276 - val_mean_absolute_percentage_error: 57.8537
# Epoch 65/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.5582 - mean_absolute_percentage_error: 6.5200 - val_loss: 98.9245 - val_mean_absolute_percentage_error: 58.3260
# Epoch 66/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.0091 - mean_absolute_percentage_error: 5.9753 - val_loss: 98.0215 - val_mean_absolute_percentage_error: 57.7426
# Epoch 67/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.3007 - mean_absolute_percentage_error: 6.2793 - val_loss: 97.7453 - val_mean_absolute_percentage_error: 57.5875
# Epoch 68/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.3046 - mean_absolute_percentage_error: 6.2494 - val_loss: 99.0209 - val_mean_absolute_percentage_error: 58.3655
# Epoch 69/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.9304 - mean_absolute_percentage_error: 5.8422 - val_loss: 97.8056 - val_mean_absolute_percentage_error: 57.6903
# Epoch 70/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.0749 - mean_absolute_percentage_error: 6.0283 - val_loss: 97.4509 - val_mean_absolute_percentage_error: 57.4741
# Epoch 71/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.9057 - mean_absolute_percentage_error: 5.7873 - val_loss: 98.0638 - val_mean_absolute_percentage_error: 57.8340
# Epoch 72/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.8110 - mean_absolute_percentage_error: 5.6673 - val_loss: 99.1284 - val_mean_absolute_percentage_error: 58.4442
# Epoch 73/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.1311 - mean_absolute_percentage_error: 5.9350 - val_loss: 98.8969 - val_mean_absolute_percentage_error: 58.2558
# Epoch 74/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.0241 - mean_absolute_percentage_error: 5.8291 - val_loss: 99.5098 - val_mean_absolute_percentage_error: 58.5569
# Epoch 75/100
# 16/16 [==============================] - 0s 7ms/step - loss: 4.7985 - mean_absolute_percentage_error: 5.6233 - val_loss: 99.5258 - val_mean_absolute_percentage_error: 58.6126
# Epoch 76/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.6599 - mean_absolute_percentage_error: 5.4928 - val_loss: 98.6966 - val_mean_absolute_percentage_error: 58.2041
# Epoch 77/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.6961 - mean_absolute_percentage_error: 5.4826 - val_loss: 100.5387 - val_mean_absolute_percentage_error: 59.1941
# Epoch 78/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.7164 - mean_absolute_percentage_error: 5.6240 - val_loss: 97.5871 - val_mean_absolute_percentage_error: 57.5220
# Epoch 79/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.3974 - mean_absolute_percentage_error: 5.1903 - val_loss: 99.0368 - val_mean_absolute_percentage_error: 58.3104
# Epoch 80/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.4942 - mean_absolute_percentage_error: 5.3454 - val_loss: 99.2560 - val_mean_absolute_percentage_error: 58.4536
# Epoch 81/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.5298 - mean_absolute_percentage_error: 5.3473 - val_loss: 98.7062 - val_mean_absolute_percentage_error: 58.1413
# Epoch 82/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.3253 - mean_absolute_percentage_error: 5.1350 - val_loss: 101.2860 - val_mean_absolute_percentage_error: 59.5926
# Epoch 83/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.6442 - mean_absolute_percentage_error: 5.4274 - val_loss: 99.6272 - val_mean_absolute_percentage_error: 58.6230
# Epoch 84/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.3824 - mean_absolute_percentage_error: 5.1860 - val_loss: 99.8592 - val_mean_absolute_percentage_error: 58.7631
# Epoch 85/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.4194 - mean_absolute_percentage_error: 5.1365 - val_loss: 100.9676 - val_mean_absolute_percentage_error: 59.3902
# Epoch 86/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.3806 - mean_absolute_percentage_error: 5.1389 - val_loss: 100.4892 - val_mean_absolute_percentage_error: 59.1214
# Epoch 87/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.1451 - mean_absolute_percentage_error: 4.8639 - val_loss: 100.3708 - val_mean_absolute_percentage_error: 59.1122
# Epoch 88/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.2411 - mean_absolute_percentage_error: 4.8895 - val_loss: 100.8677 - val_mean_absolute_percentage_error: 59.3498
# Epoch 89/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.0314 - mean_absolute_percentage_error: 4.8086 - val_loss: 100.6770 - val_mean_absolute_percentage_error: 59.2153
# Epoch 90/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.0159 - mean_absolute_percentage_error: 4.7408 - val_loss: 100.1350 - val_mean_absolute_percentage_error: 58.9207
# Epoch 91/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.2188 - mean_absolute_percentage_error: 4.9479 - val_loss: 100.9683 - val_mean_absolute_percentage_error: 59.3557
# Epoch 92/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.0554 - mean_absolute_percentage_error: 4.7904 - val_loss: 101.7398 - val_mean_absolute_percentage_error: 59.8039
# Epoch 93/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.0050 - mean_absolute_percentage_error: 4.6161 - val_loss: 101.4256 - val_mean_absolute_percentage_error: 59.6482
# Epoch 94/100
# 16/16 [==============================] - 0s 7ms/step - loss: 4.1914 - mean_absolute_percentage_error: 4.8544 - val_loss: 100.2032 - val_mean_absolute_percentage_error: 58.9548
# Epoch 95/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.0626 - mean_absolute_percentage_error: 4.7165 - val_loss: 101.2366 - val_mean_absolute_percentage_error: 59.5225
# Epoch 96/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.3049 - mean_absolute_percentage_error: 5.0113 - val_loss: 102.8847 - val_mean_absolute_percentage_error: 60.4296
# Epoch 97/100
# 16/16 [==============================] - 0s 5ms/step - loss: 3.9728 - mean_absolute_percentage_error: 4.6152 - val_loss: 102.2341 - val_mean_absolute_percentage_error: 60.0917
# Epoch 98/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.0198 - mean_absolute_percentage_error: 4.6552 - val_loss: 101.9690 - val_mean_absolute_percentage_error: 59.9705
# Epoch 99/100
# 16/16 [==============================] - 0s 5ms/step - loss: 3.9320 - mean_absolute_percentage_error: 4.6038 - val_loss: 101.9433 - val_mean_absolute_percentage_error: 59.9243
# Epoch 100/100
# 16/16 [==============================] - 0s 7ms/step - loss: 3.9745 - mean_absolute_percentage_error: 4.6322 - val_loss: 101.6529 - val_mean_absolute_percentage_error: 59.7973

# %%
# Check the dictionary keys
modeling_result=history.history
modeling_result.keys()
# Out:
# dict_keys(['loss', 'mean_absolute_percentage_error', 'val_loss', 'val_mean_absolute_percentage_error'])

# %%
# 7.2 Plot the history of training and validation
training_loss_values=modeling_result['loss']
val_loss_values=modeling_result['val_loss']
epochs=range(1,len(training_loss_values)+1)

plt.figure(figsize=(12,10),dpi=300)
plt.xlabel('Epochs',fontsize=20)
plt.ylabel('Loss (Mean absolute percentage error, MAPE)',fontsize=20)
plt.title('Rainfall ANN training & validation of Loss result ',fontsize=20)

plt.plot(epochs, training_loss_values,marker='.',label='training Loss')
plt.plot(epochs, val_loss_values,marker='.',label='validation Loss')
plt.legend(loc=1,fontsize=24)
plt.show()

# %%
# 7.2 Plot the history of training and validation
training_acc_values=modeling_result['mean_absolute_percentage_error']
val_acc_values=modeling_result['val_mean_absolute_percentage_error']
epochs=range(1,len(training_acc_values)+1)

plt.figure(figsize=(12,10),dpi=300)
plt.xlabel('Epochs',fontsize=20)
plt.ylabel('Mean Absolute Percentage Error, MAPE',fontsize=20)
plt.title('Rainfall ANN training & validation of MAPE result ',fontsize=20)

plt.plot(epochs, training_acc_values,marker='.',label='training MAPE')
plt.plot(epochs, val_acc_values,marker='.',label='validation MAPE')
plt.legend(loc=1,fontsize=24)
plt.show()

# %% [markdown]
# # Rolling 3

# %%
# 7.2 Plot the history of training and validation
training_acc_values=modeling_result['mean_absolute_percentage_error']
val_acc_values=modeling_result['val_mean_absolute_percentage_error']
epochs=range(1,len(training_acc_values)+1)

plt.figure(figsize=(12,10),dpi=300)
plt.xlabel('Epochs',fontsize=20)
plt.ylabel('Mean Absolute Percentage Error, MAPE',fontsize=20)
plt.title('Rainfall ANN training & validation of MAPE result ',fontsize=20)

plt.plot(epochs, training_acc_values,marker='.',label='training MAPE')
plt.plot(epochs, val_acc_values,marker='.',label='validation MAPE')
plt.legend(loc=1,fontsize=24)
plt.show()

# %%
##1
#set x (make prediction)
# Train
x_train=Rol_training_3.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingT=MMscaler.fit_transform(x_train)
scaled_x_train=pd.DataFrame(data=scalingT)
scaled_x_train.columns=['Lag_1','Lag_2','Lag_3']

# Validation
x_val=Rol_val_3.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingV=MMscaler.fit_transform(x_val)
scaled_x_val=pd.DataFrame(data=scalingV)
scaled_x_val.columns=['Lag_1','Lag_2','Lag_3']

#set y (want to predict)
y_train=Rol_training_3['Close'].copy()
y_val=Rol_val_3['Close'].copy()

# %%
x_train.describe()
# Out:
#             Lag_1       Lag_2       Lag_3
# count  969.000000  969.000000  969.000000
# mean   119.425686  119.274541  119.115686
# std     43.940972   43.880674   43.807882
# min     62.139999   62.139999   62.139999
# 25%     84.470001   84.269997   84.260002
# 50%    108.209999  108.209999  108.169998
# 75%    144.059998  143.720001  143.369995
# max    231.649994  231.649994  231.649994

# %%
# 7.1 Store in the history for more useful information
history=model.fit(scaled_x_train, y_train, epochs=100, batch_size=GLOBAL_BATCH_SIZE,verbose=1,validation_data=(scaled_x_val, y_val))
# Out:
# Epoch 1/100
# 16/16 [==============================] - 0s 14ms/step - loss: 30.7192 - mean_absolute_percentage_error: 24.8007 - val_loss: 123.9664 - val_mean_absolute_percentage_error: 47.4542
# Epoch 2/100
# 16/16 [==============================] - 0s 8ms/step - loss: 15.0936 - mean_absolute_percentage_error: 11.5806 - val_loss: 159.0261 - val_mean_absolute_percentage_error: 59.7456
# Epoch 3/100
# 16/16 [==============================] - 0s 8ms/step - loss: 10.7239 - mean_absolute_percentage_error: 8.4184 - val_loss: 133.1801 - val_mean_absolute_percentage_error: 50.5561
# Epoch 4/100
# 16/16 [==============================] - 0s 8ms/step - loss: 8.3298 - mean_absolute_percentage_error: 6.5263 - val_loss: 145.0548 - val_mean_absolute_percentage_error: 54.7564
# Epoch 5/100
# 16/16 [==============================] - 0s 8ms/step - loss: 7.7730 - mean_absolute_percentage_error: 6.1045 - val_loss: 144.2370 - val_mean_absolute_percentage_error: 54.5296
# Epoch 6/100
# 16/16 [==============================] - 0s 7ms/step - loss: 7.0700 - mean_absolute_percentage_error: 5.4779 - val_loss: 142.2849 - val_mean_absolute_percentage_error: 53.8407
# Epoch 7/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.5253 - mean_absolute_percentage_error: 5.8637 - val_loss: 149.2322 - val_mean_absolute_percentage_error: 56.2622
# Epoch 8/100
# 16/16 [==============================] - 0s 6ms/step - loss: 7.0544 - mean_absolute_percentage_error: 5.5124 - val_loss: 146.1655 - val_mean_absolute_percentage_error: 55.1581
# Epoch 9/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8657 - mean_absolute_percentage_error: 5.3252 - val_loss: 145.9969 - val_mean_absolute_percentage_error: 55.1168
# Epoch 10/100
# 16/16 [==============================] - 0s 6ms/step - loss: 7.0730 - mean_absolute_percentage_error: 5.4998 - val_loss: 145.7046 - val_mean_absolute_percentage_error: 55.0155
# Epoch 11/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8571 - mean_absolute_percentage_error: 5.3860 - val_loss: 147.0305 - val_mean_absolute_percentage_error: 55.4826
# Epoch 12/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.2092 - mean_absolute_percentage_error: 5.5635 - val_loss: 148.1371 - val_mean_absolute_percentage_error: 55.8791
# Epoch 13/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8232 - mean_absolute_percentage_error: 5.2526 - val_loss: 148.6929 - val_mean_absolute_percentage_error: 56.0484
# Epoch 14/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.7555 - mean_absolute_percentage_error: 5.1949 - val_loss: 147.5306 - val_mean_absolute_percentage_error: 55.6390
# Epoch 15/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4857 - mean_absolute_percentage_error: 5.0329 - val_loss: 149.7423 - val_mean_absolute_percentage_error: 56.4333
# Epoch 16/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.7405 - mean_absolute_percentage_error: 5.1535 - val_loss: 150.3098 - val_mean_absolute_percentage_error: 56.6318
# Epoch 17/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6391 - mean_absolute_percentage_error: 5.0989 - val_loss: 148.8571 - val_mean_absolute_percentage_error: 56.0852
# Epoch 18/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9368 - mean_absolute_percentage_error: 5.4394 - val_loss: 152.7420 - val_mean_absolute_percentage_error: 57.4764
# Epoch 19/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6768 - mean_absolute_percentage_error: 5.1732 - val_loss: 153.1644 - val_mean_absolute_percentage_error: 57.6300
# Epoch 20/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.7875 - mean_absolute_percentage_error: 5.2772 - val_loss: 150.2856 - val_mean_absolute_percentage_error: 56.6068
# Epoch 21/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.2352 - mean_absolute_percentage_error: 4.8103 - val_loss: 151.4284 - val_mean_absolute_percentage_error: 57.0129
# Epoch 22/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5348 - mean_absolute_percentage_error: 5.0642 - val_loss: 151.4195 - val_mean_absolute_percentage_error: 57.0171
# Epoch 23/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.2741 - mean_absolute_percentage_error: 4.8752 - val_loss: 154.3026 - val_mean_absolute_percentage_error: 58.0423
# Epoch 24/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4230 - mean_absolute_percentage_error: 5.0250 - val_loss: 152.0440 - val_mean_absolute_percentage_error: 57.2287
# Epoch 25/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.5096 - mean_absolute_percentage_error: 5.0011 - val_loss: 150.0661 - val_mean_absolute_percentage_error: 56.5183
# Epoch 26/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1156 - mean_absolute_percentage_error: 4.7823 - val_loss: 154.3701 - val_mean_absolute_percentage_error: 58.0694
# Epoch 27/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.4619 - mean_absolute_percentage_error: 4.8644 - val_loss: 153.0096 - val_mean_absolute_percentage_error: 57.5967
# Epoch 28/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.6090 - mean_absolute_percentage_error: 4.9607 - val_loss: 151.9899 - val_mean_absolute_percentage_error: 57.1862
# Epoch 29/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2441 - mean_absolute_percentage_error: 4.9291 - val_loss: 154.9445 - val_mean_absolute_percentage_error: 58.2376
# Epoch 30/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.2394 - mean_absolute_percentage_error: 4.7549 - val_loss: 155.3883 - val_mean_absolute_percentage_error: 58.4173
# Epoch 31/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3666 - mean_absolute_percentage_error: 4.9092 - val_loss: 156.0304 - val_mean_absolute_percentage_error: 58.6164
# Epoch 32/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.0458 - mean_absolute_percentage_error: 4.6397 - val_loss: 155.2128 - val_mean_absolute_percentage_error: 58.3299
# Epoch 33/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.8780 - mean_absolute_percentage_error: 4.4612 - val_loss: 156.1492 - val_mean_absolute_percentage_error: 58.6654
# Epoch 34/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.0261 - mean_absolute_percentage_error: 4.5610 - val_loss: 153.8787 - val_mean_absolute_percentage_error: 57.8355
# Epoch 35/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.2286 - mean_absolute_percentage_error: 4.7663 - val_loss: 154.9827 - val_mean_absolute_percentage_error: 58.2291
# Epoch 36/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2499 - mean_absolute_percentage_error: 4.7769 - val_loss: 155.6882 - val_mean_absolute_percentage_error: 58.4896
# Epoch 37/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.7842 - mean_absolute_percentage_error: 4.4610 - val_loss: 157.0526 - val_mean_absolute_percentage_error: 58.9699
# Epoch 38/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.6701 - mean_absolute_percentage_error: 4.3408 - val_loss: 156.8915 - val_mean_absolute_percentage_error: 58.9137
# Epoch 39/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.7251 - mean_absolute_percentage_error: 4.5016 - val_loss: 154.2667 - val_mean_absolute_percentage_error: 57.9739
# Epoch 40/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.6206 - mean_absolute_percentage_error: 4.3742 - val_loss: 155.1361 - val_mean_absolute_percentage_error: 58.2780
# Epoch 41/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.6949 - mean_absolute_percentage_error: 4.3701 - val_loss: 157.4318 - val_mean_absolute_percentage_error: 59.1090
# Epoch 42/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.8997 - mean_absolute_percentage_error: 4.6230 - val_loss: 158.8964 - val_mean_absolute_percentage_error: 59.6279
# Epoch 43/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1829 - mean_absolute_percentage_error: 4.7733 - val_loss: 156.7197 - val_mean_absolute_percentage_error: 58.8276
# Epoch 44/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.8362 - mean_absolute_percentage_error: 4.5404 - val_loss: 153.3705 - val_mean_absolute_percentage_error: 57.6318
# Epoch 45/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.9357 - mean_absolute_percentage_error: 4.5890 - val_loss: 154.9995 - val_mean_absolute_percentage_error: 58.2488
# Epoch 46/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.4987 - mean_absolute_percentage_error: 4.2426 - val_loss: 155.5713 - val_mean_absolute_percentage_error: 58.4524
# Epoch 47/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.3373 - mean_absolute_percentage_error: 4.1734 - val_loss: 156.6447 - val_mean_absolute_percentage_error: 58.8295
# Epoch 48/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.3941 - mean_absolute_percentage_error: 4.1739 - val_loss: 157.3624 - val_mean_absolute_percentage_error: 59.0726
# Epoch 49/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.4131 - mean_absolute_percentage_error: 4.2110 - val_loss: 155.1580 - val_mean_absolute_percentage_error: 58.3142
# Epoch 50/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.6609 - mean_absolute_percentage_error: 4.3783 - val_loss: 157.6517 - val_mean_absolute_percentage_error: 59.1846
# Epoch 51/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.6969 - mean_absolute_percentage_error: 4.4456 - val_loss: 156.3372 - val_mean_absolute_percentage_error: 58.7214
# Epoch 52/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.5905 - mean_absolute_percentage_error: 4.2851 - val_loss: 155.1177 - val_mean_absolute_percentage_error: 58.2805
# Epoch 53/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.8133 - mean_absolute_percentage_error: 4.4869 - val_loss: 155.5420 - val_mean_absolute_percentage_error: 58.4418
# Epoch 54/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.5573 - mean_absolute_percentage_error: 4.2574 - val_loss: 156.5938 - val_mean_absolute_percentage_error: 58.7941
# Epoch 55/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.1128 - mean_absolute_percentage_error: 4.0618 - val_loss: 157.8979 - val_mean_absolute_percentage_error: 59.2371
# Epoch 56/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.5189 - mean_absolute_percentage_error: 4.2734 - val_loss: 153.1226 - val_mean_absolute_percentage_error: 57.5732
# Epoch 57/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.5335 - mean_absolute_percentage_error: 4.3276 - val_loss: 156.8729 - val_mean_absolute_percentage_error: 58.9141
# Epoch 58/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.6700 - mean_absolute_percentage_error: 4.4479 - val_loss: 159.2746 - val_mean_absolute_percentage_error: 59.7292
# Epoch 59/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.6566 - mean_absolute_percentage_error: 4.4686 - val_loss: 156.6946 - val_mean_absolute_percentage_error: 58.8055
# Epoch 60/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.5886 - mean_absolute_percentage_error: 4.3619 - val_loss: 156.1288 - val_mean_absolute_percentage_error: 58.6220
# Epoch 61/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.3152 - mean_absolute_percentage_error: 4.1158 - val_loss: 157.5615 - val_mean_absolute_percentage_error: 59.1324
# Epoch 62/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.5460 - mean_absolute_percentage_error: 4.3164 - val_loss: 159.3270 - val_mean_absolute_percentage_error: 59.7241
# Epoch 63/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.2975 - mean_absolute_percentage_error: 4.1140 - val_loss: 158.3873 - val_mean_absolute_percentage_error: 59.3998
# Epoch 64/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.5587 - mean_absolute_percentage_error: 4.2691 - val_loss: 157.6530 - val_mean_absolute_percentage_error: 59.1516
# Epoch 65/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.3195 - mean_absolute_percentage_error: 4.1490 - val_loss: 156.6891 - val_mean_absolute_percentage_error: 58.8210
# Epoch 66/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.4128 - mean_absolute_percentage_error: 4.2472 - val_loss: 157.3229 - val_mean_absolute_percentage_error: 59.0499
# Epoch 67/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.3130 - mean_absolute_percentage_error: 4.2229 - val_loss: 156.2731 - val_mean_absolute_percentage_error: 58.6861
# Epoch 68/100
# 16/16 [==============================] - 0s 7ms/step - loss: 5.2393 - mean_absolute_percentage_error: 4.0621 - val_loss: 156.2594 - val_mean_absolute_percentage_error: 58.6678
# Epoch 69/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.1050 - mean_absolute_percentage_error: 4.0693 - val_loss: 156.2406 - val_mean_absolute_percentage_error: 58.6477
# Epoch 70/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.4800 - mean_absolute_percentage_error: 4.3146 - val_loss: 155.5440 - val_mean_absolute_percentage_error: 58.4145
# Epoch 71/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.1620 - mean_absolute_percentage_error: 4.0721 - val_loss: 158.5511 - val_mean_absolute_percentage_error: 59.4766
# Epoch 72/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.3800 - mean_absolute_percentage_error: 4.3024 - val_loss: 157.7770 - val_mean_absolute_percentage_error: 59.1996
# Epoch 73/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.1060 - mean_absolute_percentage_error: 3.9874 - val_loss: 157.0931 - val_mean_absolute_percentage_error: 58.9619
# Epoch 74/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.3927 - mean_absolute_percentage_error: 4.2573 - val_loss: 155.0143 - val_mean_absolute_percentage_error: 58.2221
# Epoch 75/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.1448 - mean_absolute_percentage_error: 4.0237 - val_loss: 158.0738 - val_mean_absolute_percentage_error: 59.3092
# Epoch 76/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.3307 - mean_absolute_percentage_error: 4.1330 - val_loss: 158.6182 - val_mean_absolute_percentage_error: 59.4877
# Epoch 77/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.0624 - mean_absolute_percentage_error: 3.9930 - val_loss: 157.8540 - val_mean_absolute_percentage_error: 59.2145
# Epoch 78/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.2113 - mean_absolute_percentage_error: 4.1121 - val_loss: 158.1634 - val_mean_absolute_percentage_error: 59.3474
# Epoch 79/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.0746 - mean_absolute_percentage_error: 3.9935 - val_loss: 156.8323 - val_mean_absolute_percentage_error: 58.8606
# Epoch 80/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.3735 - mean_absolute_percentage_error: 4.1920 - val_loss: 158.3676 - val_mean_absolute_percentage_error: 59.4147
# Epoch 81/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.2629 - mean_absolute_percentage_error: 4.1262 - val_loss: 156.7984 - val_mean_absolute_percentage_error: 58.8297
# Epoch 82/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.0111 - mean_absolute_percentage_error: 4.0353 - val_loss: 157.2562 - val_mean_absolute_percentage_error: 59.0000
# Epoch 83/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.1550 - mean_absolute_percentage_error: 3.9999 - val_loss: 156.2778 - val_mean_absolute_percentage_error: 58.6657
# Epoch 84/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.0071 - mean_absolute_percentage_error: 3.9983 - val_loss: 156.5609 - val_mean_absolute_percentage_error: 58.7825
# Epoch 85/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.1402 - mean_absolute_percentage_error: 4.0393 - val_loss: 157.3038 - val_mean_absolute_percentage_error: 59.0417
# Epoch 86/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.1089 - mean_absolute_percentage_error: 3.9891 - val_loss: 158.8956 - val_mean_absolute_percentage_error: 59.5986
# Epoch 87/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.1714 - mean_absolute_percentage_error: 4.0587 - val_loss: 159.5475 - val_mean_absolute_percentage_error: 59.8198
# Epoch 88/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.2202 - mean_absolute_percentage_error: 4.1796 - val_loss: 158.4330 - val_mean_absolute_percentage_error: 59.4053
# Epoch 89/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.1603 - mean_absolute_percentage_error: 4.0292 - val_loss: 159.4022 - val_mean_absolute_percentage_error: 59.7645
# Epoch 90/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.7771 - mean_absolute_percentage_error: 3.7269 - val_loss: 157.4314 - val_mean_absolute_percentage_error: 59.0784
# Epoch 91/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.0962 - mean_absolute_percentage_error: 3.9906 - val_loss: 157.4445 - val_mean_absolute_percentage_error: 59.0747
# Epoch 92/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.0369 - mean_absolute_percentage_error: 3.9642 - val_loss: 153.9462 - val_mean_absolute_percentage_error: 57.8517
# Epoch 93/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.0129 - mean_absolute_percentage_error: 3.9632 - val_loss: 156.6904 - val_mean_absolute_percentage_error: 58.8121
# Epoch 94/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.8064 - mean_absolute_percentage_error: 3.8584 - val_loss: 158.4866 - val_mean_absolute_percentage_error: 59.4320
# Epoch 95/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.5629 - mean_absolute_percentage_error: 4.3025 - val_loss: 160.1761 - val_mean_absolute_percentage_error: 60.0370
# Epoch 96/100
# 16/16 [==============================] - 0s 6ms/step - loss: 5.2645 - mean_absolute_percentage_error: 4.0195 - val_loss: 158.1961 - val_mean_absolute_percentage_error: 59.3323
# Epoch 97/100
# 16/16 [==============================] - 0s 5ms/step - loss: 5.1644 - mean_absolute_percentage_error: 4.0401 - val_loss: 157.8348 - val_mean_absolute_percentage_error: 59.1936
# Epoch 98/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.9476 - mean_absolute_percentage_error: 3.8826 - val_loss: 158.2324 - val_mean_absolute_percentage_error: 59.3471
# Epoch 99/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.9152 - mean_absolute_percentage_error: 3.8667 - val_loss: 158.0138 - val_mean_absolute_percentage_error: 59.2848
# Epoch 100/100
# 16/16 [==============================] - 0s 5ms/step - loss: 4.9729 - mean_absolute_percentage_error: 3.9174 - val_loss: 158.3894 - val_mean_absolute_percentage_error: 59.4173

# %%
# Check the dictionary keys
modeling_result=history.history
modeling_result.keys()
# Out:
# dict_keys(['loss', 'mean_absolute_percentage_error', 'val_loss', 'val_mean_absolute_percentage_error'])

# %%
# 7.2 Plot the history of training and validation
training_loss_values=modeling_result['loss']
val_loss_values=modeling_result['val_loss']
epochs=range(1,len(training_loss_values)+1)

plt.figure(figsize=(12,10),dpi=300)
plt.xlabel('Epochs',fontsize=20)
plt.ylabel('Loss (Mean absolute percentage error, MAPE)',fontsize=20)
plt.title('Rainfall ANN training & validation of Loss result ',fontsize=20)

plt.plot(epochs, training_loss_values,marker='.',label='training Loss')
plt.plot(epochs, val_loss_values,marker='.',label='validation Loss')
plt.legend(loc=1,fontsize=24)
plt.show()

# %%
# 7.2 Plot the history of training and validation
training_acc_values=modeling_result['mean_absolute_percentage_error']
val_acc_values=modeling_result['val_mean_absolute_percentage_error']
epochs=range(1,len(training_acc_values)+1)

plt.figure(figsize=(12,10),dpi=300)
plt.xlabel('Epochs',fontsize=20)
plt.ylabel('Mean Absolute Percentage Error, MAPE',fontsize=20)
plt.title('Rainfall ANN training & validation of MAPE result ',fontsize=20)

plt.plot(epochs, training_acc_values,marker='.',label='training MAPE')
plt.plot(epochs, val_acc_values,marker='.',label='validation MAPE')
plt.legend(loc=1,fontsize=24)
plt.show()

# %% [markdown]
# # Fit the final model with all of the training data

# %%
# X all train data
x_forecast_train=Forecast_train_data.drop(['Date','Close'],axis=1).copy()
# Y all train data
y_forecast_train=Forecast_train_data['Close'].copy()

# %%
# Create the model
clear.clear_session()
Fmodel=Sequential()

# 6.2 Add input layer & first hidden layer
Fmodel.add(Dense(units=6, input_dim=3, activation='relu'))

# 6.3 Add second hidden layer
Fmodel.add(Dense(units=12, activation='linear'))

Fmodel.add(Dropout(rate=0.2))

# 6.4 Add third hidden layer
Fmodel.add(Dense(units=24, activation='linear'))

Fmodel.add(Dense(units=48, activation='relu'))

Fmodel.add(Dropout(rate=0.4))

Fmodel.add(Dense(units=96, activation='relu'))

# 6.5 Add output layer
Fmodel.add(Dense(units=1, activation='linear'))

# Compile the defined Net
#opt=SGD(learning_rate=0.001,momentum=0.5)
opt=Adam(learning_rate=GLOBAL_LEARNING_RATE,beta_1=0.95)
Fmodel.compile(loss='my_RMSE', optimizer=opt, metrics=['mean_absolute_percentage_error'])

# Finally check the model 
Fmodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 24
#
#  dense_1 (Dense)             (None, 12)                84
#
#  dropout (Dropout)           (None, 12)                0
#
#  dense_2 (Dense)             (None, 24)                312
#
#  dense_3 (Dense)             (None, 48)                1200
#
#  dropout_1 (Dropout)         (None, 48)                0
#
#  dense_4 (Dense)             (None, 96)                4704
#
#  dense_5 (Dense)             (None, 1)                 97
#
# =================================================================
# Total params: 6,421
# Trainable params: 6,421
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Store in the history for more useful information
history=Fmodel.fit(x_forecast_train, y_forecast_train, epochs=100, batch_size=GLOBAL_BATCH_SIZE,verbose=1)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 1s 3ms/step - loss: 53.7887 - mean_absolute_percentage_error: 43.6997
# Epoch 2/100
# 31/31 [==============================] - 0s 3ms/step - loss: 24.1883 - mean_absolute_percentage_error: 19.7631
# Epoch 3/100
# 31/31 [==============================] - 0s 3ms/step - loss: 19.4875 - mean_absolute_percentage_error: 15.7513
# Epoch 4/100
# 31/31 [==============================] - 0s 3ms/step - loss: 16.8176 - mean_absolute_percentage_error: 13.6137
# Epoch 5/100
# 31/31 [==============================] - 0s 3ms/step - loss: 14.2501 - mean_absolute_percentage_error: 11.5015
# Epoch 6/100
# 31/31 [==============================] - 0s 3ms/step - loss: 13.2006 - mean_absolute_percentage_error: 10.7187
# Epoch 7/100
# 31/31 [==============================] - 0s 3ms/step - loss: 12.3760 - mean_absolute_percentage_error: 10.1478
# Epoch 8/100
# 31/31 [==============================] - 0s 3ms/step - loss: 11.3189 - mean_absolute_percentage_error: 9.4643
# Epoch 9/100
# 31/31 [==============================] - 0s 3ms/step - loss: 10.6100 - mean_absolute_percentage_error: 8.5958
# Epoch 10/100
# 31/31 [==============================] - 0s 2ms/step - loss: 9.5494 - mean_absolute_percentage_error: 7.7937
# Epoch 11/100
# 31/31 [==============================] - 0s 3ms/step - loss: 9.6593 - mean_absolute_percentage_error: 7.9547
# Epoch 12/100
# 31/31 [==============================] - 0s 3ms/step - loss: 9.1165 - mean_absolute_percentage_error: 7.4556
# Epoch 13/100
# 31/31 [==============================] - 0s 3ms/step - loss: 8.8066 - mean_absolute_percentage_error: 7.3212
# Epoch 14/100
# 31/31 [==============================] - 0s 3ms/step - loss: 8.3715 - mean_absolute_percentage_error: 7.0229
# Epoch 15/100
# 31/31 [==============================] - 0s 3ms/step - loss: 8.1898 - mean_absolute_percentage_error: 6.7052
# Epoch 16/100
# 31/31 [==============================] - 0s 3ms/step - loss: 8.5019 - mean_absolute_percentage_error: 7.0806
# Epoch 17/100
# 31/31 [==============================] - 0s 3ms/step - loss: 8.1349 - mean_absolute_percentage_error: 6.5951
# Epoch 18/100
# 31/31 [==============================] - 0s 3ms/step - loss: 7.8590 - mean_absolute_percentage_error: 6.3308
# Epoch 19/100
# 31/31 [==============================] - 0s 3ms/step - loss: 7.8777 - mean_absolute_percentage_error: 6.3692
# Epoch 20/100
# 31/31 [==============================] - 0s 3ms/step - loss: 7.4281 - mean_absolute_percentage_error: 6.1319
# Epoch 21/100
# 31/31 [==============================] - 0s 2ms/step - loss: 7.1793 - mean_absolute_percentage_error: 5.7582
# Epoch 22/100
# 31/31 [==============================] - 0s 3ms/step - loss: 6.9496 - mean_absolute_percentage_error: 5.7166
# Epoch 23/100
# 31/31 [==============================] - 0s 3ms/step - loss: 7.6448 - mean_absolute_percentage_error: 6.2617
# Epoch 24/100
# 31/31 [==============================] - 0s 3ms/step - loss: 7.0690 - mean_absolute_percentage_error: 5.7527
# Epoch 25/100
# 31/31 [==============================] - 0s 3ms/step - loss: 6.5342 - mean_absolute_percentage_error: 5.4065
# Epoch 26/100
# 31/31 [==============================] - 0s 2ms/step - loss: 6.3889 - mean_absolute_percentage_error: 5.3450
# Epoch 27/100
# 31/31 [==============================] - 0s 3ms/step - loss: 7.1061 - mean_absolute_percentage_error: 5.7537
# Epoch 28/100
# 31/31 [==============================] - 0s 3ms/step - loss: 6.7524 - mean_absolute_percentage_error: 5.5700
# Epoch 29/100
# 31/31 [==============================] - 0s 2ms/step - loss: 6.3845 - mean_absolute_percentage_error: 5.2137
# Epoch 30/100
# 31/31 [==============================] - 0s 3ms/step - loss: 6.3433 - mean_absolute_percentage_error: 5.1952
# Epoch 31/100
# 31/31 [==============================] - 0s 3ms/step - loss: 6.2505 - mean_absolute_percentage_error: 5.0430
# Epoch 32/100
# 31/31 [==============================] - 0s 2ms/step - loss: 6.0659 - mean_absolute_percentage_error: 4.9403
# Epoch 33/100
# 31/31 [==============================] - 0s 2ms/step - loss: 5.8280 - mean_absolute_percentage_error: 4.9224
# Epoch 34/100
# 31/31 [==============================] - 0s 3ms/step - loss: 5.9061 - mean_absolute_percentage_error: 4.7728
# Epoch 35/100
# 31/31 [==============================] - 0s 3ms/step - loss: 6.1047 - mean_absolute_percentage_error: 4.9796
# Epoch 36/100
# 31/31 [==============================] - 0s 2ms/step - loss: 5.9015 - mean_absolute_percentage_error: 4.9246
# Epoch 37/100
# 31/31 [==============================] - 0s 3ms/step - loss: 5.9965 - mean_absolute_percentage_error: 4.7968
# Epoch 38/100
# 31/31 [==============================] - 0s 2ms/step - loss: 5.4517 - mean_absolute_percentage_error: 4.4612
# Epoch 39/100
# 31/31 [==============================] - 0s 3ms/step - loss: 5.2399 - mean_absolute_percentage_error: 4.3916
# Epoch 40/100
# 31/31 [==============================] - 0s 3ms/step - loss: 5.4861 - mean_absolute_percentage_error: 4.5506
# Epoch 41/100
# 31/31 [==============================] - 0s 3ms/step - loss: 5.5914 - mean_absolute_percentage_error: 4.5536
# Epoch 42/100
# 31/31 [==============================] - 0s 3ms/step - loss: 5.6136 - mean_absolute_percentage_error: 4.5111
# Epoch 43/100
# 31/31 [==============================] - 0s 3ms/step - loss: 5.3938 - mean_absolute_percentage_error: 4.3737
# Epoch 44/100
# 31/31 [==============================] - 0s 2ms/step - loss: 5.7137 - mean_absolute_percentage_error: 4.5116
# Epoch 45/100
# 31/31 [==============================] - 0s 2ms/step - loss: 5.0904 - mean_absolute_percentage_error: 4.1135
# Epoch 46/100
# 31/31 [==============================] - 0s 3ms/step - loss: 5.1158 - mean_absolute_percentage_error: 4.2422
# Epoch 47/100
# 31/31 [==============================] - 0s 2ms/step - loss: 5.1927 - mean_absolute_percentage_error: 4.1902
# Epoch 48/100
# 31/31 [==============================] - 0s 3ms/step - loss: 4.9619 - mean_absolute_percentage_error: 4.0775
# Epoch 49/100
# 31/31 [==============================] - 0s 2ms/step - loss: 5.0193 - mean_absolute_percentage_error: 4.0772
# Epoch 50/100
# 31/31 [==============================] - 0s 3ms/step - loss: 5.0118 - mean_absolute_percentage_error: 4.1744
# Epoch 51/100
# 31/31 [==============================] - 0s 3ms/step - loss: 4.9589 - mean_absolute_percentage_error: 3.9985
# Epoch 52/100
# 31/31 [==============================] - 0s 4ms/step - loss: 5.1215 - mean_absolute_percentage_error: 4.0096
# Epoch 53/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.8202 - mean_absolute_percentage_error: 3.9739
# Epoch 54/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.8797 - mean_absolute_percentage_error: 3.9280
# Epoch 55/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.8948 - mean_absolute_percentage_error: 4.0858
# Epoch 56/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.7317 - mean_absolute_percentage_error: 3.9462
# Epoch 57/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.8559 - mean_absolute_percentage_error: 3.9585
# Epoch 58/100
# 31/31 [==============================] - 0s 4ms/step - loss: 5.1496 - mean_absolute_percentage_error: 4.1120
# Epoch 59/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.4849 - mean_absolute_percentage_error: 3.6634
# Epoch 60/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.9960 - mean_absolute_percentage_error: 4.1517
# Epoch 61/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.9558 - mean_absolute_percentage_error: 4.0106
# Epoch 62/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.2752 - mean_absolute_percentage_error: 3.5728
# Epoch 63/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.5874 - mean_absolute_percentage_error: 3.6305
# Epoch 64/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.7287 - mean_absolute_percentage_error: 3.8031
# Epoch 65/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.4207 - mean_absolute_percentage_error: 3.6387
# Epoch 66/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.5909 - mean_absolute_percentage_error: 3.7481
# Epoch 67/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.4626 - mean_absolute_percentage_error: 3.6153
# Epoch 68/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.5301 - mean_absolute_percentage_error: 3.6122
# Epoch 69/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.2421 - mean_absolute_percentage_error: 3.3840
# Epoch 70/100
# 31/31 [==============================] - 0s 3ms/step - loss: 4.5087 - mean_absolute_percentage_error: 3.7321
# Epoch 71/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.3555 - mean_absolute_percentage_error: 3.5302
# Epoch 72/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.4883 - mean_absolute_percentage_error: 3.5614
# Epoch 73/100
# 31/31 [==============================] - 0s 4ms/step - loss: 3.9577 - mean_absolute_percentage_error: 3.2058
# Epoch 74/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.5710 - mean_absolute_percentage_error: 3.7128
# Epoch 75/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.2904 - mean_absolute_percentage_error: 3.5651
# Epoch 76/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.4446 - mean_absolute_percentage_error: 3.6257
# Epoch 77/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.0010 - mean_absolute_percentage_error: 3.2850
# Epoch 78/100
# 31/31 [==============================] - 0s 3ms/step - loss: 4.4148 - mean_absolute_percentage_error: 3.5418
# Epoch 79/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.5100 - mean_absolute_percentage_error: 3.6561
# Epoch 80/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.2145 - mean_absolute_percentage_error: 3.5298
# Epoch 81/100
# 31/31 [==============================] - 0s 4ms/step - loss: 3.9901 - mean_absolute_percentage_error: 3.3268
# Epoch 82/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.2707 - mean_absolute_percentage_error: 3.4146
# Epoch 83/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.4884 - mean_absolute_percentage_error: 3.5557
# Epoch 84/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.1586 - mean_absolute_percentage_error: 3.5034
# Epoch 85/100
# 31/31 [==============================] - 0s 4ms/step - loss: 3.8895 - mean_absolute_percentage_error: 3.2149
# Epoch 86/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.0862 - mean_absolute_percentage_error: 3.3811
# Epoch 87/100
# 31/31 [==============================] - 0s 4ms/step - loss: 4.0868 - mean_absolute_percentage_error: 3.2865
# Epoch 88/100
# 31/31 [==============================] - 0s 4ms/step - loss: 3.8548 - mean_absolute_percentage_error: 3.1915
# Epoch 89/100
# 31/31 [==============================] - 0s 4ms/step - loss: 3.6576 - mean_absolute_percentage_error: 2.9899
# Epoch 90/100
# 31/31 [==============================] - 0s 3ms/step - loss: 3.8737 - mean_absolute_percentage_error: 3.2363
# Epoch 91/100
# 31/31 [==============================] - 0s 3ms/step - loss: 4.1313 - mean_absolute_percentage_error: 3.1969
# Epoch 92/100
# 31/31 [==============================] - 0s 3ms/step - loss: 4.0859 - mean_absolute_percentage_error: 3.2624
# Epoch 93/100
# 31/31 [==============================] - 0s 2ms/step - loss: 4.0708 - mean_absolute_percentage_error: 3.2501
# Epoch 94/100
# 31/31 [==============================] - 0s 3ms/step - loss: 4.0436 - mean_absolute_percentage_error: 3.3113
# Epoch 95/100
# 31/31 [==============================] - 0s 2ms/step - loss: 3.9683 - mean_absolute_percentage_error: 3.2820
# Epoch 96/100
# 31/31 [==============================] - 0s 3ms/step - loss: 3.9842 - mean_absolute_percentage_error: 3.1763
# Epoch 97/100
# 31/31 [==============================] - 0s 3ms/step - loss: 3.8593 - mean_absolute_percentage_error: 3.2033
# Epoch 98/100
# 31/31 [==============================] - 0s 3ms/step - loss: 3.6619 - mean_absolute_percentage_error: 3.0026
# Epoch 99/100
# 31/31 [==============================] - 0s 3ms/step - loss: 3.6290 - mean_absolute_percentage_error: 2.9114
# Epoch 100/100
# 31/31 [==============================] - 0s 3ms/step - loss: 3.9548 - mean_absolute_percentage_error: 3.1085

# %%
# 7.3 Save the trained model
#Fmodel.save('D:/data_analysis/PyExport/Rainfall_forecast_ANN_trained_model.h5')
# Colab
Fmodel.save('House_Rent_ANN_trained_model.h5')
print('Model has been saved...')
# Out:
# Model has been saved...

# %%
# 7.4 Restore the saved model for testing
#ANN_model=keras.models.load_model('D:/data_analysis/PyExport/Rainfall_forecast_ANN_trained_model.h5')
# Colab
ANN_model=keras.models.load_model('/content/House_Rent_ANN_trained_model.h5')
print('Model successfully loaded...')
# Out:
# Model successfully loaded...

# %% [markdown]
# # 8. Testing

# %%
# X test
x_forecast_test=Forecast_test_data.drop(['Date','Close'],axis=1).copy()
# Y test
y_forecast_test=Forecast_test_data['Close'].copy()

# %%
# 8.1 Make prediction 
prediction=np.round((ANN_model.predict_on_batch(x_forecast_test)),2)
pred_values=[]
for i in range(0,len(prediction)):
    value=prediction[i][0]
    pred_values.append(value)

# %%
Results=pd.DataFrame({'Date':Forecast_test_data['Date'],'Y_true':Forecast_test_data['Close'],'Predict':pred_values})
Results['abs Error']=np.abs(Results['Y_true']-Results['Predict'])
Results
# Out:
#            Date      Y_true     Predict   abs Error
# 1938  14/2/2022  295.000000  140.309998  154.690002
# 1939  15/2/2022  300.470001  139.089996  161.380005
# 1940  16/2/2022  299.500000  141.490005  158.009995
# 1941  17/2/2022  290.730011  142.910004  147.820007
# 1942  18/2/2022  287.929993  139.490005  148.439988
# ...         ...         ...         ...         ...
# 2256  22/5/2023  321.179993  151.559998  169.619995
# 2257  23/5/2023  315.260010  151.779999  163.480011
# 2258  24/5/2023  313.850006  151.009995  162.840011
# 2259  25/5/2023  325.920013  148.440002  177.480011
# 2260  26/5/2023  332.890015  152.080002  180.810013
#
# [323 rows x 4 columns]

# %%
# 8.2 Calculating the mertics
MAE=mean_absolute_error(y_forecast_test,pred_values)
MSE=mean_squared_error(y_forecast_test,pred_values,squared=True)
RMSE=mean_squared_error(y_forecast_test,pred_values,squared=False)
MAPE=mean_absolute_percentage_error(y_forecast_test,pred_values)
SMAPE=SMAPE_calulate(y_forecast_test,pred_values)
RAE=RAE_calculate(y_forecast_test,pred_values)
MRAE=MRAE_calculate(y_forecast_test,pred_values)
MdRAE=MdRAE_calculate(y_forecast_test,pred_values)
RSE=RSE_calculate(y_forecast_test,pred_values,Root=False)
RRSE=RSE_calculate(y_forecast_test,pred_values,Root=True)

print('MAE:',round(MAE,3))
print('MSE:',round(MSE,3))
print('RMSE:',round(RMSE,3))
print('MAPE:',round(MAPE*100,3),'%')
print('SMAPE:',round(SMAPE,3),'%')
print('RAE:',round(RAE,3))
print('MRAE:',MRAE)
print('MdRAE:',round(MdRAE[0],3),'bench:',round(MdRAE[1],3))
print('RSE:',round(RSE,3))
print('RRSE:',round(RRSE,3))
# Out:
# MAE: 140.193
# MSE: 19843.554
# RMSE: 140.867
# MAPE: 52.551 %
# SMAPE: 71.297 %
# RAE: 6.764
# MRAE: 0.020941571129216675
# MdRAE: 7.327 bench: 266.683
# RSE: 33.008
# RRSE: 5.745

# %% [markdown]
# #  Plot for comparing true value & predicted value

# %%
# Plot Y and its corresponding date
# Figure setting
plt.figure(figsize=(24,8),dpi=300)
plt.title('Monthly Relative Humidity Forecast Comparison (2018-2020)',weight='bold',fontsize=24)
plt.xlabel('Date',fontsize=18,weight='bold')
plt.ylabel('Relative Humidity',fontsize=18,weight='bold')

# Comparison of actual value and predicted value according to Date
plt.plot(clean_df.iloc[1800:,0],clean_df.iloc[1800:,1],marker='o',color='blue',label='Actual')
plt.plot(Results['Date'],Results['Predict'],marker='o',color='red',label='Forecast')

# Set the axis
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# Set legends
plt.legend(loc=4,fontsize=20)

plt.show()
